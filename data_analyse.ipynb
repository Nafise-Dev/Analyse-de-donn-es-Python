# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafise-Dev/Analyse-de-donnees-Python/blob/main/data_analyse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plot

df = pd.read_csv (r'/content/drive/MyDrive/house_pricing.csv')
# df
# print (df.dtypes)
# data = pd.DataFrame(data=df, columns=['LotArea','SalePrice'])
# sb.regplot(x=df["SalePrice"], y=df["LotArea"], fit_reg=True)
# df[(df['SalePrice'] < 500000) & (df['LotArea'] < 20000)].plot.scatter(x = 'SalePrice', y = 'LotArea');
data2 = pd.DataFrame(data=df, columns=['LotArea', 'LotFrontage'])
# sb.regplot(x=df["LotFrontage"], y=df["LotArea"], fit_reg=True)
df[(df['LotFrontage'] < 200) & (df['LotArea'] < 10000)].plot.scatter(x = 'LotFrontage', y = 'LotArea');
plot.show();

# %%
data = pd.read_csv(r'/content/drive/MyDrive/sales_predictions.csv')
print(data.dtypes)
df = pd.DataFrame(data=data, columns=['item_price','date'])
# df
sb.relplot(x=df["date"], y=df["item_price"])
plot.show();
# Out:
# date               object
# date_block_num      int64
# shop_id             int64
# item_id             int64
# item_price        float64
# item_cnt_day      float64
# dtype: object

# %%
df = pd.DataFrame(data=data, columns=['item_price','date']).sample(n=50)
sb.relplot(x=df["date"], y=df["item_price"])
plot.show();

# %%
sb.relplot(x=df["date"], y=df["item_price"], s=120)
plot.show();

# %%
df = pd.DataFrame(data=data, columns=['date','item_price']).sample(n=50)
value=pd.to_datetime(df["date"], infer_datetime_format=True)
sb.relplot(x=value, y=df["item_price"], s=50)
plot.show();
